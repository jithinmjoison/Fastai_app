# %% [markdown]
# <a href="https://colab.research.google.com/github/jithinmjoison/Fastai_app/blob/main/Linear_regression_in_pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### Chapter 1 ####

''' Simple Linear Regression in Numpy'''


import numpy as np
from sklearn.linear_model import LinearRegression
import torch

import torch.optim as optim
import torch.nn as nn
from torchviz import make_dot

# %%
# !pip install torchviz
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...

# %%
## generate Synthetic Data  ###



true_b= 1
true_w = 2
N = 100

np.random.seed(42)

x = np.random.rand(N,1)

epsilon = (0.1*np.random.randn(N,1))

y = true_b + true_w * x + epsilon

# %%
## Shuffling the data####

idx = np.arange(N)

np.random.shuffle(idx)

####

train_idx = idx[:int(N * 0.8)]
val_idx = idx[int(N*0.8):]

x_train = x[train_idx]
y_train = y[train_idx]

x_test = x[val_idx]
y_test = y[val_idx]

# %%
### Gradient Descent ###

''' Step 0 Random Initialisation'''

np.random.seed(42)

b = np.random.rand(1)

w = np.random.rand(1)

print(w,b)

'''Step 1 - compute model's prediction -forwrad pass'''

y_hat = b + w * x_train

'''Compute the loss '''

error = y_hat - y_train

loss = np.mean(error **2)

print(loss)

''' Step 3 Compute Gradients'''

b_grad = 2 * error.mean()

w_grad = 2 * (x_train * error).mean()

print(b_grad,w_grad)

'''Step 4 Update the parameters'''

lr = 0.01

b = b - lr * b_grad

w = w - lr * w_grad

print(b,w)
# Out:
# [0.95071431] [0.37454012]
# 1.3823577862834915
# -2.2601640738070934 -1.2588049395456
# [0.39714176] [0.96330236]

# %%
np.random.seed(42)

b = np.random.rand(1)

w = np.random.rand(1)

print(w,b)
# Out:
# [0.95071431] [0.37454012]

# %%
''' Updating the learning parameters'''

lr = 0.1

print(b,w)

b = b - lr * b_grad

w = w - lr * w_grad

print(b,w)
# Out:
# [0.39714176] [0.96330236]
# [0.62315817] [1.08918285]

# %%
lr =0.1
n_epochs = 1000

for epoch in range(n_epochs):
  y_hat = b + w * x_train

  error = y_hat - y_train

  loss = np.mean(error**2)


  b_grad = 2 * error.mean()
  w_grad = 2 * (x_train * error).mean()

  b = b - lr * b_grad
  w = w - lr * w_grad

  print(f'Epoch {epoch} Loss is {loss}')
# Out:
# Epoch 0 Loss is 1.3823577862834915
# Epoch 1 Loss is 0.7960549739717951
# Epoch 2 Loss is 0.4644122869503568
# Epoch 3 Loss is 0.2766796964374806
# Epoch 4 Loss is 0.1702758016443195
# Epoch 5 Loss is 0.10983767227004093
# Epoch 6 Loss is 0.07538262334915559
# Epoch 7 Loss is 0.05561883465452968
# Epoch 8 Loss is 0.044165407886443735
# Epoch 9 Loss is 0.037416448682388345
# Epoch 10 Loss is 0.03333413141294652
# Epoch 11 Loss is 0.030766700712816942
# Epoch 12 Loss is 0.02906309699970644
# Epoch 13 Loss is 0.027855194175426236
# Epoch 14 Loss is 0.026934749304453942
# Epoch 15 Loss is 0.026183870831621665
# Epoch 16 Loss is 0.025535728321063194
# Epoch 17 Loss is 0.024952350661325576
# Epoch 18 Loss is 0.02441208039023747
# Epoch 19 Loss is 0.02390248437197489
# Epoch 20 Loss is 0.023416347679658906
# Epoch 21 Loss is 0.022949409698464443
# Epoch 22 Loss is 0.02249908470383244
# Epoch 23 Loss is 0.022063738738346033
# Epoch 24 Loss is 0.02164228083910486
# ...

# %%
print(b,w)
# Out:
# [1.02354082] [1.96896434]

# %%
### Synthetic Data Generation ###

true_b = 1
true_w = 2
N = 100

np.random.seed(42)

x = np.random.rand(N,1)

epsilon = (0.1 * np.random.randn(N,1))

y = true_b + true_w * x + epsilon

# %%
from re import I
### Shuffles the indexes###

idx = np.arange(N)

np.random.shuffle(idx)

### Train ###

train_idx = idx[:int(N*.8)]

val_idx = idx[int(N*.8):]

x_train = x[train_idx]

y_train = y[train_idx]

### Test ###

x_test = x[val_idx]

y_test = y[val_idx]

# %%
### Gradient Descent ###

## Step 0 Random Intialisation ##


np.random.rand(42)
b = np.random.rand(1)
w = np.random.rand(1)

print(b,w)
# Out:
# [0.37461261] [0.62585992]

# %%
##Step 1 Forward Pass###

yhat = b+ w *  x_train

## Step 2 Loss

error = (yhat- y_train)

loss = np.mean(error **2)

### Computing the gradients for b and w since its a simple linear function

b_grad = 2 * error.mean()

w_grad = 2 * error.mean() * x_train

### Setting the learning rate

lr = 0.01

### Updating the parameters
b = b -lr * b_grad

w = w - lr * w_grad

# %%
### Using Numpy to implement linear regression ###

np.random.rand(42)

b = np.random.rand(1)

w = np.random.rand(1)

print(b,w)

lr = 0.01

n_epochs = 1000

for epoch in range(n_epochs):

      yhat = b+ w* x_train

      error = yhat - y_train

      loss = np.mean(error **2)

      b_grad = 2 * error.mean()

      w_grad = 2 * ( error * x_train).mean()

      b = b - lr * b_grad

      w = w - lr * w_grad

      print(f'Epoch {epoch} Loss is {loss}')

print(b, w)
# Out:
# [0.28377591] [0.3630823]
# Epoch 0 Loss is 2.4953107777916004
# Epoch 1 Loss is 2.37748625954233
# Epoch 2 Loss is 2.2654275163567346
# Epoch 3 Loss is 2.158851822408251
# Epoch 4 Loss is 2.0574903171254664
# Epoch 5 Loss is 1.9610873252160759
# Epoch 6 Loss is 1.8693997100380582
# Epoch 7 Loss is 1.7821962586826536
# Epoch 8 Loss is 1.6992570972139558
# Epoch 9 Loss is 1.6203731345861705
# Epoch 10 Loss is 1.545345533832148
# Epoch 11 Loss is 1.4739852091857528
# Epoch 12 Loss is 1.4061123478662334
# Epoch 13 Loss is 1.3415559553151206
# Epoch 14 Loss is 1.2801534227355054
# Epoch 15 Loss is 1.2217501158399457
# Epoch 16 Loss is 1.1661989837668956
# Epoch 17 Loss is 1.1133601871765548
# Epoch 18 Loss is 1.0631007445855503
# Epoch 19 Loss is 1.0152941960459807
# Epoch 20 Loss is 0.9698202833182303
# Epoch 21 Loss is 0.9265646457286664
# Epoch 22 Loss is 0.8854185309430058
# Epoch 23 Loss is 0.8462785199238615
# Epoch 24 Loss is 0.8090462653768531
# ...

# %%
## Using Scikit learn Regresion Package ##

linr = LinearRegression()

linr.fit(x_train,y_train)

print(linr.intercept_,linr.coef_[0])
# Out:
# [1.02354075] [1.96896447]

# %%
print(b, w)
# Out:
# [1.02354082] [1.96896434]

# %%
### Pytorch###

x_train_tensor = torch.as_tensor(x_train)

x_train.dtype , x_train_tensor.dtype
# Out:
# (dtype('float64'), torch.float64)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
n_cudas = torch.cuda.device_count()
for i in range(n_cudas):
  print(torch.cuda.get_device_name(i))
